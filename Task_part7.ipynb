# %% [markdown]
# # Задача 1
# Даны две переменные x=1 и y=5. Поменять менстами переменные, чтобы x=5, а y=1

# %%
x=1
y=5

# %% [markdown]
# # Задача 2
# Даны списки A и B, найдите общие элементы (пересечение) и элементы, которые встречаются только в A

# %%
A =[1, 4, 67, 8, 9, 10, 'a', 'n']
B =[4, 3,'c', 'a', 10, 8]

# %% [markdown]
# # Задача 3
# Из списка A задачи 2, составьте множество, добавьте любой элемент, удалите элемент 'n'

# %% [markdown]
# # Задача 4
# - Создать матрицу из натуральных чисел от 1 до 20 размером 9 на 9.
# - Заменить диагональные элементы на нули.
# - Далее элемент [5][3] заменить на 100.
# - Весь 3 столбец кроме элемента [3][3] заменить на единицы.

# %% [markdown]
# # Задача 5
# Написать функцию, которая будет находить корни квадратного уравнения с задаваемыми коэффициентами a,b,c. На вход функции подаем эти коэффициенты, на выходе получаем корни уравнения.
#
# - Напомню: вид уравнения a*x^2+b*x+c=0

# %% [markdown]
# # Задача 6
# Написать функцию калькулятора банковского вклада. На входе процентная ставка, сумма вклада, сколько лет планируется держать вклад и параметр, указывающий на то, снимаются ли проценты со счета каждый год или остаются.
#
# - если проценты снимаются, то: S = x*(1+(b/100)*n)
# - если проценты остаются, то на сумму начисляемых процентов каждый год будут начисляется еще проценты: S = x*(1+b/100)^n
# - где S - итоговая сумма денег после вклада, х - сумма вклада, b- процент вклада, n - количество лет

# %% [markdown]
# # Задача 7
# Написать функцию, которая принимает на вход год и возвращает високосны или невисокосный год

# %% [markdown]
# # Задача 8
# Вводятся 3 числа, требуется найти наибольшее из них.

# %% [markdown]
# # Задача 9
#
# написать функцию расчета факториала, на вход подается число, на выходе факториал этого числа.
#
# - Факториал числа
# ![image.png](attachment:image.png)

# %% [markdown]
# # Задача 10
#
# Написать функцию,выдающую несколько чисел фибоначи. На вход подается n количество числе, на выходе список из чисел фибоначи.
#
#
#
# ![image.png](attachment:image.png)
